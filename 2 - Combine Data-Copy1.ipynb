# %%
import os
import pandas as pd

# %%
cwd = os.getcwd() # dirname(abspath(__file__))
BASE_DIR = os.path.join(cwd)
DATA_DIR = os.path.join(BASE_DIR, 'data')
CACHE_DIR = os.path.join(BASE_DIR, 'cache')
os.makedirs(CACHE_DIR, exist_ok=True)

# %%
for filename in os.listdir(DATA_DIR):
    print(filename)
# Out:
# 1999.csv
# 2000.csv
# 2001.csv
# 2002.csv
# 2003.csv
# 2004.csv
# 2005.csv
# 2006.csv
# 2007.csv
# 2008.csv
# 2009.csv
# 2010.csv
# 2011.csv
# 2012.csv
# 2013.csv
# 2014.csv
# 2015.csv
# 2016.csv
# 2017.csv
# 2018.csv
# 2019.csv
# 2020.csv

# %%
df = pd.read_csv(os.path.join(DATA_DIR, '2010.csv'))

# %%
df.head()
# Out:
#    Rank                                 Release Group       Worldwide  \
# 0     1                                   Toy Story 3  $1,066,969,703
# 1     2                           Alice in Wonderland  $1,025,467,110
# 2     3  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3     4                                     Inception    $828,322,032
# 4     5                           Shrek Forever After    $752,600,867
#
#        Domestic      %       Foreign    %.1
# 0  $415,004,880  38.9%  $651,964,823  61.1%
# 1  $334,191,110  32.6%  $691,276,000  67.4%
# 2  $295,983,305  30.3%  $680,553,613  69.7%
# 3  $292,576,195  35.3%  $535,745,837  64.7%
# 4  $238,736,787  31.7%  $513,864,080  68.3%

# %%
df['Year'] = 2010

# %%
df.head()
# Out:
#    Rank                                 Release Group       Worldwide  \
# 0     1                                   Toy Story 3  $1,066,969,703
# 1     2                           Alice in Wonderland  $1,025,467,110
# 2     3  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3     4                                     Inception    $828,322,032
# 4     5                           Shrek Forever After    $752,600,867
#
#        Domestic      %       Foreign    %.1  Year
# 0  $415,004,880  38.9%  $651,964,823  61.1%  2010
# 1  $334,191,110  32.6%  $691,276,000  67.4%  2010
# 2  $295,983,305  30.3%  $680,553,613  69.7%  2010
# 3  $292,576,195  35.3%  $535,745,837  64.7%  2010
# 4  $238,736,787  31.7%  $513,864,080  68.3%  2010

# %%
my_dataframe = []
csv_file = [x for x in os.listdir(DATA_DIR) if x.endswith(".csv")]
for filename in os.listdir(DATA_DIR):
    print(filename)
    year = filename.replace(".csv","")
    csv_path = os.path.join(DATA_DIR,filename)
    this_df = pd.read_csv(csv_path)
    this_df['filename'] = filename
    this_df['year'] = year
    print(this_df.head(n=1))
    my_dataframe.append(this_df)
# Out:
# 1999.csv
#    Rank                              Release Group     Worldwide  \
# 0     1  Star Wars: Episode I - The Phantom Menace  $924,305,084
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $431,088,295  46.6%  $493,216,789  53.4%  1999.csv  1999
# 2000.csv
#    Rank           Release Group     Worldwide      Domestic      %  \
# 0     1  Mission: Impossible II  $546,388,108  $215,409,889  39.4%
#
#         Foreign    %.1  filename  year
# 0  $330,978,219  60.6%  2000.csv  2000
# 2001.csv
#    Rank                          Release Group     Worldwide      Domestic  \
# 0     1  Harry Potter and the Sorcerer's Stone  $974,755,371  $317,575,550
#
#        %       Foreign    %.1  filename  year
# 0  32.6%  $657,179,821  67.4%  2001.csv  2001
# 2002.csv
#    Rank                          Release Group     Worldwide      Domestic  \
# 0     1  The Lord of the Rings: The Two Towers  $936,689,735  $339,789,881
#
#        %       Foreign    %.1  filename  year
# ...

# %%
my_dataframe
# Out:
# [     Rank                              Release Group     Worldwide  \
#  0       1  Star Wars: Episode I - The Phantom Menace  $924,305,084
#  1       2                            The Sixth Sense  $672,806,292
#  2       3                                Toy Story 2  $487,059,677
#  3       4                                 The Matrix  $463,517,383
#  4       5                                     Tarzan  $448,191,819
#  ..    ...                                        ...           ...
#  381   382                 The Sticky Fingers of Time        $1,610
#  382   383                                Summerspell          $984
#  383   384               The Underground Comedy Movie          $856
#  384   385                                 Port Djema          $783
#  385   386                                     Nobody          $488
#
#           Domestic      %       Foreign    %.1  filename  year
#  0    $431,088,295  46.6%  $493,216,789  53.4%  1999.csv  1999
# ...

# %%
my_entire_dataframe = pd.concat(my_dataframe)

# %%
my_entire_dataframe
# Out:
#     Rank                              Release Group     Worldwide  \
# 0      1  Star Wars: Episode I - The Phantom Menace  $924,305,084
# 1      2                            The Sixth Sense  $672,806,292
# 2      3                                Toy Story 2  $487,059,677
# 3      4                                 The Matrix  $463,517,383
# 4      5                                     Tarzan  $448,191,819
# ..   ...                                        ...           ...
# 27    28                                     Burden      $139,270
# 28    29                         14 Days, 12 Nights      $122,806
# 29    30                                  First Cow      $101,068
# 30    31                                        Run        $4,052
# 31    32                      A Quiet Place Part II          $159
#
#         Domestic      %       Foreign    %.1  filename  year
# 0   $431,088,295  46.6%  $493,216,789  53.4%  1999.csv  1999
# ...

# %%
my_entire_dataframe.tail()
# Out:
#     Rank          Release Group Worldwide  Domestic      % Foreign   %.1  \
# 27    28                 Burden  $139,270  $139,270   100%       -     -
# 28    29     14 Days, 12 Nights  $122,806  $122,530  99.8%    $276  0.2%
# 29    30              First Cow  $101,068  $101,068   100%       -     -
# 30    31                    Run    $4,052         -      -  $4,052  100%
# 31    32  A Quiet Place Part II      $159         -      -    $159  100%
#
#     filename  year
# 27  2020.csv  2020
# 28  2020.csv  2020
# 29  2020.csv  2020
# 30  2020.csv  2020
# 31  2020.csv  2020

# %%
dataset = os.path.join(CACHE_DIR, 'movies_box_office_dataset.csv')

# %%
my_entire_dataframe.to_csv(dataset, index=False)
