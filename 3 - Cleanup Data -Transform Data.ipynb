# %%
! pip install ufl
import os
import pandas as pd
from ufl import replace
# Out:
# Collecting ufl
#   Downloading UFL-2017.1.0.tar.gz (301 kB)
# Requirement already satisfied: numpy in c:\users\danish\appdata\local\programs\python\python37-32\lib\site-packages (from ufl) (1.17.4)
# Requirement already satisfied: six in c:\users\danish\appdata\roaming\python\python37\site-packages (from ufl) (1.12.0)
# Building wheels for collected packages: ufl
#   Building wheel for ufl (setup.py): started
#   Building wheel for ufl (setup.py): finished with status 'done'
#   Created wheel for ufl: filename=UFL-2017.1.0-py3-none-any.whl size=290096 sha256=c32a15575599352a8a4dffe84875a406807faf425877016b975073dca2d4654b
#   Stored in directory: c:\users\danish\appdata\local\pip\cache\wheels\0f\99\88\13f9480bc59a5464386b6a26a451293cb5dd9653de1dc9e32c
# Successfully built ufl
# Installing collected packages: ufl
# Successfully installed ufl-2017.1.0

# %%
cwd = os.getcwd() # dirname(abspath(__file__))
BASE_DIR = os.path.join(cwd)
DATA_DIR = os.path.join(BASE_DIR, 'data')
CACHE_DIR = os.path.join(BASE_DIR, 'cache')
working_file = os.path.join(CACHE_DIR,'movies_box_office_dataset.csv')

# %%
df = pd.read_csv(working_file)

# %%
df.head(n=1000)
# Out:
#      Rank                              Release Group     Worldwide  \
# 0       1  Star Wars: Episode I - The Phantom Menace  $924,305,084
# 1       2                            The Sixth Sense  $672,806,292
# 2       3                                Toy Story 2  $487,059,677
# 3       4                                 The Matrix  $463,517,383
# 4       5                                     Tarzan  $448,191,819
# ..    ...                                        ...           ...
# 995   233                           Ashoka the Great    $1,340,718
# 996   234                               Storytelling    $1,318,945
# 997   235                                   Yamakasi    $1,297,401
# 998   236                  The Business of Strangers    $1,287,598
# 999   237                               The Believer    $1,274,112
#
#          Domestic      %       Foreign    %.1  filename  year
# 0    $431,088,295  46.6%  $493,216,789  53.4%  1999.csv  1999
# 1    $293,506,292  43.6%  $379,300,000  56.4%  1999.csv  1999
# 2    $245,852,179  50.5%  $241,207,498  49.5%  1999.csv  1999
# 3    $171,479,930    37%  $292,037,453    63%  1999.csv  1999
# 4    $171,091,819  38.2%  $277,100,000  61.8%  1999.csv  1999
# ..            ...    ...           ...    ...       ...   ...
# 995      $731,277  54.5%      $609,441  45.5%  2001.csv  2001
# 996      $921,445  69.9%      $397,500  30.1%  2001.csv  2001
# 997      $184,441  14.2%    $1,112,960  85.8%  2001.csv  2001
# 998    $1,030,920  80.1%      $256,678  19.9%  2001.csv  2001
# 999      $416,925  32.7%      $857,187  67.3%  2001.csv  2001
#
# [1000 rows x 9 columns]

# %%
df['Rank'] = -1

# %%
df.head()
# Out:
#    Rank                              Release Group     Worldwide  \
# 0    -1  Star Wars: Episode I - The Phantom Menace  $924,305,084
# 1    -1                            The Sixth Sense  $672,806,292
# 2    -1                                Toy Story 2  $487,059,677
# 3    -1                                 The Matrix  $463,517,383
# 4    -1                                     Tarzan  $448,191,819
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $431,088,295  46.6%  $493,216,789  53.4%  1999.csv  1999
# 1  $293,506,292  43.6%  $379,300,000  56.4%  1999.csv  1999
# 2  $245,852,179  50.5%  $241,207,498  49.5%  1999.csv  1999
# 3  $171,479,930    37%  $292,037,453    63%  1999.csv  1999
# 4  $171,091,819  38.2%  $277,100,000  61.8%  1999.csv  1999

# %%
df['Domestiic %'] = df['%']

# %%
df['Foreign %'] = df['%.1']

# %%
df
# Out:
#        Rank                              Release Group     Worldwide  \
# 0        -1  Star Wars: Episode I - The Phantom Menace  $924,305,084
# 1        -1                            The Sixth Sense  $672,806,292
# 2        -1                                Toy Story 2  $487,059,677
# 3        -1                                 The Matrix  $463,517,383
# 4        -1                                     Tarzan  $448,191,819
# ...     ...                                        ...           ...
# 12927    -1                                     Burden      $139,270
# 12928    -1                         14 Days, 12 Nights      $122,806
# 12929    -1                                  First Cow      $101,068
# 12930    -1                                        Run        $4,052
# 12931    -1                      A Quiet Place Part II          $159
#
#            Domestic      %       Foreign    %.1  filename  year Domestiic %  \
# 0      $431,088,295  46.6%  $493,216,789  53.4%  1999.csv  1999       46.6%
# 1      $293,506,292  43.6%  $379,300,000  56.4%  1999.csv  1999       43.6%
# 2      $245,852,179  50.5%  $241,207,498  49.5%  1999.csv  1999       50.5%
# 3      $171,479,930    37%  $292,037,453    63%  1999.csv  1999         37%
# 4      $171,091,819  38.2%  $277,100,000  61.8%  1999.csv  1999       38.2%
# ...             ...    ...           ...    ...       ...   ...         ...
# 12927      $139,270   100%             -      -  2020.csv  2020        100%
# 12928      $122,530  99.8%          $276   0.2%  2020.csv  2020       99.8%
# 12929      $101,068   100%             -      -  2020.csv  2020        100%
# 12930             -      -        $4,052   100%  2020.csv  2020           -
# 12931             -      -          $159   100%  2020.csv  2020           -
#
#       Foreign %
# 0         53.4%
# 1         56.4%
# 2         49.5%
# 3           63%
# 4         61.8%
# ...         ...
# 12927         -
# 12928      0.2%
# 12929         -
# 12930      100%
# 12931      100%
#
# [12932 rows x 11 columns]

# %%
df.drop(['%','%.1'],axis=1)
# Out:
#        Rank                              Release Group     Worldwide  \
# 0        -1  Star Wars: Episode I - The Phantom Menace  $924,305,084
# 1        -1                            The Sixth Sense  $672,806,292
# 2        -1                                Toy Story 2  $487,059,677
# 3        -1                                 The Matrix  $463,517,383
# 4        -1                                     Tarzan  $448,191,819
# ...     ...                                        ...           ...
# 12927    -1                                     Burden      $139,270
# 12928    -1                         14 Days, 12 Nights      $122,806
# 12929    -1                                  First Cow      $101,068
# 12930    -1                                        Run        $4,052
# 12931    -1                      A Quiet Place Part II          $159
#
#            Domestic       Foreign  filename  year Domestiic % Foreign %
# 0      $431,088,295  $493,216,789  1999.csv  1999       46.6%     53.4%
# 1      $293,506,292  $379,300,000  1999.csv  1999       43.6%     56.4%
# 2      $245,852,179  $241,207,498  1999.csv  1999       50.5%     49.5%
# 3      $171,479,930  $292,037,453  1999.csv  1999         37%       63%
# 4      $171,091,819  $277,100,000  1999.csv  1999       38.2%     61.8%
# ...             ...           ...       ...   ...         ...       ...
# 12927      $139,270             -  2020.csv  2020        100%         -
# 12928      $122,530          $276  2020.csv  2020       99.8%      0.2%
# 12929      $101,068             -  2020.csv  2020        100%         -
# 12930             -        $4,052  2020.csv  2020           -      100%
# 12931             -          $159  2020.csv  2020           -      100%
#
# [12932 rows x 9 columns]

# %%
df = df.drop(['%','%.1'],axis=1)

# %%
df.head(5)
# Out:
#    Rank                              Release Group     Worldwide  \
# 0    -1  Star Wars: Episode I - The Phantom Menace  $924,305,084
# 1    -1                            The Sixth Sense  $672,806,292
# 2    -1                                Toy Story 2  $487,059,677
# 3    -1                                 The Matrix  $463,517,383
# 4    -1                                     Tarzan  $448,191,819
#
#        Domestic       Foreign  filename  year Domestiic % Foreign %
# 0  $431,088,295  $493,216,789  1999.csv  1999       46.6%     53.4%
# 1  $293,506,292  $379,300,000  1999.csv  1999       43.6%     56.4%
# 2  $245,852,179  $241,207,498  1999.csv  1999       50.5%     49.5%
# 3  $171,479,930  $292,037,453  1999.csv  1999         37%       63%
# 4  $171,091,819  $277,100,000  1999.csv  1999       38.2%     61.8%

# %%
def claen_col(row):
    row['Worldwide'] = row['Worldwide'].replcae
    return row
df = df.apply(clean_col,axis=1)
df.head(n=5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-a3d5aa01e7fa> in <module>
#       2     row['Worldwide'] = row['Worldwide']
#       3     return row
# ----> 4 df = df.apply(clean_col,axis=1)
#       5 df.head(n=5)
#
# c:\users\danish\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# c:\users\danish\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# c:\users\danish\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-47-795184cc916c> in clean_col(row)
#       5     """
#       6     #print(row)
# ----> 7     row['Worldwide'] = row['Worldwide'].replace("$",''),replace(',','')
#       8     return row
#       9
#
# c:\users\danish\appdata\local\programs\python\python37-32\lib\site-packages\ufl\algorithms\replace.py in replace(e, mapping)
#      61         A dict with from:to replacements to perform.
#      62     """
# ---> 63     mapping2 = dict((k, as_ufl(v)) for (k, v) in iteritems(mapping))
#      64
#      65     # Workaround for problem with delayed derivative evaluation
#
# C:\Users\DANISH\AppData\Roaming\Python\Python37\site-packages\six.py in iteritems(d, **kw)
#     585
#     586     def iteritems(d, **kw):
# --> 587         return iter(d.items(**kw))
#     588
#     589     def iterlists(d, **kw):
#
# AttributeError: 'str' object has no attribute 'items'
